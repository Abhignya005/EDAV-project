# %%
"""Title:
    Problem Statement:Analyze pest incidence and control measures across crops and states.
    Project ID:CBIT/IT-1/EDAV/2025/CEP-35
    Roll No:160124737005
    Name of the Student:Bodikela Abhignya
    Department of IT
    Chaitanya Bharathi Institute of Technology,Hyderabad

Problem Overview:This assignment focuses on analyzing pest incidence data across crops and states. Tasks include calculating average incidence,
filtering by crop, imputing missing values, grouping by pest type and region, and visualizing trends over years. It emphasizes data cleaning,
aggregation, and exploratory analysis, building practical skills in data handling and interpretation.
    

DataSetLink:
          https://drive.google.com/drive/u/0/folders/1KAlqhbXo7ssDEO3wsJ7oGU03PUTp-RoS

Environment:
            python --version:  Python 3.13.7
            Libraries Used:numpy  pandas"""

# %%
#Loading the data set
import numpy as np
import pandas as pd
df = pd.read_csv("C:\\Users\\abhignya\\Downloads\\Pest_Incidence_and_Control_India_500rows.csv")
print(df)
# Out:
#      Record_ID       Crop             State   Region         Pest_Name  \
# 0            1      Onion             Bihar     East          Whitefly
# 1            2      Onion         Jharkhand     East   Tikka Leaf Spot
# 2            3  Sugarcane       Maharashtra     West            Aphids
# 3            4      Apple  Himachal Pradesh    North            Thrips
# 4            5       Rice             Assam     East        Stem Borer
# ..         ...        ...               ...      ...               ...
# 495        496     Cotton       Uttarakhand    North  Tea Mosquito Bug
# 496        497  Sugarcane        Tamil Nadu    South       Fruit Borer
# 497        498  Sugarcane      Chhattisgarh  Central       Late Blight
# 498        499       Okra    Andhra Pradesh    South        Stem Borer
# 499        500    Soybean      Chhattisgarh  Central          Whitefly
#
#     Pest_Type Month_Reported  Incidence_Percent Incidence_Level  \
# 0      Insect          March               58.2          Medium
# 1      Fungal          April               59.9          Medium
# 2      Insect      September               35.8          Medium
# 3      Insect        October               66.8            High
# 4      Insect        January               14.2             Low
# ..        ...            ...                ...             ...
# 495    Insect           July               39.6          Medium
# 496    Insect            May               34.3          Medium
# 497    Fungal        January               34.4          Medium
# 498    Insect      September               79.6            High
# 499    Insect           June               48.0          Medium
#
#                       Probable_Cause                   Recommended_Control  \
# 0                     Delayed sowing    Crop rotation and field sanitation
# 1                 Uncontrolled weeds             Adopt resistant varieties
# 2            Continuous monocropping         Use sticky traps and neem oil
# 3                     Delayed sowing    Crop rotation and field sanitation
# 4                      High humidity          Apply recommended fungicides
# ..                               ...                                   ...
# 495               Uncontrolled weeds    Use pheromone traps and neem spray
# 496  Heavy rainfall and waterlogging    Use pheromone traps and neem spray
# 497               Uncontrolled weeds          Apply recommended fungicides
# 498          High temperature stress  Integrated Pest Management practices
# 499              Excess nitrogen use          Apply recommended fungicides
#
#     Control_Type                  Source  Imputed_Flag  \
# 0       Cultural     Farmer field report         False
# 1       Cultural  State Agriculture Dept         False
# 2            IPM  State Agriculture Dept         False
# 3       Cultural               KVK alert         False
# 4       Chemical  State Agriculture Dept         False
# ..           ...                     ...           ...
# 495   Biological     Farmer field report         False
# 496   Biological             PPQS report         False
# 497     Chemical             PPQS report         False
# 498          IPM     Farmer field report         False
# 499     Chemical             PPQS report         False
#
#      Incidence_Percent_Imputed  Year
# 0                         58.2  2025
# 1                         59.9  2025
# 2                         35.8  2025
# 3                         66.8  2025
# 4                         14.2  2025
# ..                         ...   ...
# 495                       39.6  2025
# 496                       34.3  2025
# 497                       34.4  2025
# 498                       79.6  2025
# 499                       48.0  2025
#
# [500 rows x 16 columns]

# %%
# Question 1: Calculate average pest incidence rate (Bloom's level-3)

# Compute the overall average of the column 'Incidence_Percent_Imputed'
# This column represents the pest incidence percentage 
overall_avg = df["Incidence_Percent_Imputed"].mean()

# Print the calculated average pest incidence rate
print(overall_avg)
# Out:
# 48.7712

# %%
#Question 2:Filter pest reports by crop type (Bloom's level-3)
# Define the crop of interest
crop = "Rice"

# Filter the DataFrame to include only rows where the 'Crop' column matches the specified crop
filtered_df = df[df["Crop"] == crop]

# Print the filtered DataFrame
# The output will show all the data related to the crop "Rice" only
print(filtered_df)
# Out:
#      Record_ID  Crop           State   Region           Pest_Name Pest_Type  \
# 4            5  Rice           Assam     East          Stem Borer    Insect
# 28          29  Rice       Jharkhand     East    Tea Mosquito Bug    Insect
# 63          64  Rice          Punjab    North     Tikka Leaf Spot    Fungal
# 73          74  Rice     Maharashtra     West          Stem Borer    Insect
# 76          77  Rice   Uttar Pradesh    North               Blast    Fungal
# 104        105  Rice          Punjab    North              Aphids    Insect
# 106        107  Rice       Telangana    South     Tikka Leaf Spot    Fungal
# 117        118  Rice  Madhya Pradesh  Central          Stem Borer    Insect
# 120        121  Rice      Tamil Nadu    South            Sigatoka    Fungal
# 132        133  Rice     Uttarakhand    North    Tea Mosquito Bug    Insect
# 137        138  Rice         Gujarat     West     Tikka Leaf Spot    Fungal
# 168        169  Rice       Telangana    South           Leaf Rust    Fungal
# 176        177  Rice     West Bengal     East  Coffee Berry Borer    Insect
# 253        254  Rice           Bihar     East            Whitefly    Insect
# 260        261  Rice           Bihar     East  Coffee Berry Borer    Insect
# 275        276  Rice          Punjab    North                Wilt    Fungal
# 343        344  Rice          Kerala    South       Fall Armyworm    Insect
# 355        356  Rice      Tamil Nadu    South           Leaf Rust    Fungal
# 362        363  Rice      Tamil Nadu    South  Coffee Berry Borer    Insect
# 453        454  Rice     Maharashtra     West     Tikka Leaf Spot    Fungal
#
#     Month_Reported  Incidence_Percent Incidence_Level  \
# 4          January               14.2             Low
# 28       September               13.3             Low
# 63           April               35.3          Medium
# 73             May               38.3          Medium
# 76            July               54.7          Medium
# 104       February               59.4          Medium
# 106           June               36.0          Medium
# 117          March                NaN             NaN
# 120       December               71.7            High
# 132           June               29.1             Low
# 137         August               76.6            High
# 168      September               49.2          Medium
# 176           July               34.3          Medium
# 253       February               16.1             Low
# 260         August               35.3          Medium
# 275         August               52.8          Medium
# 343            May               76.7            High
# 355          March               21.4             Low
# 362          April               78.1            High
# 453         August               42.4          Medium
#
#                       Probable_Cause                   Recommended_Control  \
# 4                      High humidity          Apply recommended fungicides
# 28               Excess nitrogen use      Release Trichogramma parasitoids
# 63              Invasive pest spread    Use pheromone traps and neem spray
# 73           High temperature stress  Integrated Pest Management practices
# 76                    Delayed sowing    Crop rotation and field sanitation
# 104          Continuous monocropping             Adopt resistant varieties
# 106  Heavy rainfall and waterlogging  Integrated Pest Management practices
# 117        Unbalanced fertilizer use    Crop rotation and field sanitation
# 120  Heavy rainfall and waterlogging          Apply recommended fungicides
# 132          Continuous monocropping             Adopt resistant varieties
# 137  Heavy rainfall and waterlogging         Use sticky traps and neem oil
# 168                    Poor drainage    Use pheromone traps and neem spray
# 176               Uncontrolled weeds          Apply recommended fungicides
# 253               Uncontrolled weeds    Crop rotation and field sanitation
# 260                   Delayed sowing             Adopt resistant varieties
# 275             Invasive pest spread    Crop rotation and field sanitation
# 343  Heavy rainfall and waterlogging    Use pheromone traps and neem spray
# 355        Unbalanced fertilizer use    Crop rotation and field sanitation
# 362  Heavy rainfall and waterlogging    Crop rotation and field sanitation
# 453              Excess nitrogen use             Adopt resistant varieties
#
#     Control_Type                  Source  Imputed_Flag  \
# 4       Chemical  State Agriculture Dept         False
# 28    Biological               KVK alert         False
# 63    Biological             PPQS report         False
# 73           IPM     Farmer field report         False
# 76      Cultural  State Agriculture Dept         False
# 104     Cultural               KVK alert         False
# 106          IPM     Farmer field report         False
# 117     Cultural               KVK alert          True
# 120     Chemical           ICAR advisory         False
# 132     Cultural     Farmer field report         False
# 137          IPM           ICAR advisory         False
# 168   Biological  State Agriculture Dept         False
# 176     Chemical             PPQS report         False
# 253     Cultural             PPQS report         False
# 260     Cultural           ICAR advisory         False
# 275     Cultural  State Agriculture Dept         False
# 343   Biological  State Agriculture Dept         False
# 355     Cultural             PPQS report         False
# 362     Cultural     Farmer field report         False
# 453     Cultural               KVK alert         False
#
#      Incidence_Percent_Imputed  Year
# 4                         14.2  2025
# 28                        13.3  2025
# 63                        35.3  2025
# 73                        38.3  2025
# 76                        54.7  2025
# 104                       59.4  2025
# 106                       36.0  2025
# 117                       37.5  2025
# 120                       71.7  2025
# 132                       29.1  2025
# 137                       76.6  2025
# 168                       49.2  2025
# 176                       34.3  2025
# 253                       16.1  2025
# 260                       35.3  2025
# 275                       52.8  2025
# 343                       76.7  2025
# 355                       21.4  2025
# 362                       78.1  2025
# 453                       42.4  2025

# %%
# Define the crop of interest
crop = "Potato"

# Filter the DataFrame to include only rows where the 'Crop' column matches the specified crop
filtered_df = df[df["Crop"] == crop]

# Print the filtered DataFrame
# The output will show all the data related to the crop "Potato" only
print(filtered_df)
# Out:
#      Record_ID    Crop             State   Region           Pest_Name  \
# 9           10  Potato       Uttarakhand    North    Tea Mosquito Bug
# 56          57  Potato             Assam     East    Tea Mosquito Bug
# 74          75  Potato             Assam     East   Brown Planthopper
# 112        113  Potato           Haryana    North  Coffee Berry Borer
# 121        122  Potato         Rajasthan     West                Wilt
# 128        129  Potato    Andhra Pradesh    South                Wilt
# 135        136  Potato        Tamil Nadu    South            Whitefly
# 205        206  Potato    Andhra Pradesh    South          Stem Borer
# 209        210  Potato       West Bengal     East    Tea Mosquito Bug
# 215        216  Potato             Assam     East       Fall Armyworm
# 263        264  Potato             Assam     East         Fruit Borer
# 294        295  Potato        Tamil Nadu    South            Sigatoka
# 316        317  Potato    Madhya Pradesh  Central         Fruit Borer
# 356        357  Potato            Kerala    South          Stem Borer
# 370        371  Potato       West Bengal     East           Leaf Rust
# 391        392  Potato            Odisha     East            Sigatoka
# 456        457  Potato  Himachal Pradesh    North     Tikka Leaf Spot
# 467        468  Potato       Maharashtra     West              Thrips
# 468        469  Potato         Jharkhand     East   Brown Planthopper
#
#     Pest_Type Month_Reported  Incidence_Percent Incidence_Level  \
# 9      Insect         August               82.9            High
# 56     Insect      September               76.1            High
# 74     Insect       December               83.5            High
# 112    Insect      September               30.0          Medium
# 121    Fungal       February               88.6            High
# 128    Fungal           July               20.8             Low
# 135    Insect          April               55.7          Medium
# 205    Insect        January               73.7            High
# 209    Insect           June               48.3          Medium
# 215    Insect          March               72.8            High
# 263    Insect       November               24.4             Low
# 294    Fungal          March               87.5            High
# 316    Insect           June               50.3          Medium
# 356    Insect           July               72.7            High
# 370    Fungal        October               42.3          Medium
# 391    Fungal       February               34.1          Medium
# 456    Fungal          March               44.9          Medium
# 467    Insect         August               43.3          Medium
# 468    Insect        January               30.9          Medium
#
#                       Probable_Cause                   Recommended_Control  \
# 9               Invasive pest spread         Use sticky traps and neem oil
# 56               Excess nitrogen use    Use pheromone traps and neem spray
# 74                    Delayed sowing    Crop rotation and field sanitation
# 112          High temperature stress         Use sticky traps and neem oil
# 121  Heavy rainfall and waterlogging  Integrated Pest Management practices
# 128                    High humidity  Integrated Pest Management practices
# 135          High temperature stress             Adopt resistant varieties
# 205        Unbalanced fertilizer use         Use sticky traps and neem oil
# 209  Heavy rainfall and waterlogging         Use sticky traps and neem oil
# 215        Unbalanced fertilizer use    Use pheromone traps and neem spray
# 263                   Delayed sowing    Use pheromone traps and neem spray
# 294  Heavy rainfall and waterlogging  Integrated Pest Management practices
# 316          High temperature stress    Crop rotation and field sanitation
# 356          Continuous monocropping    Use pheromone traps and neem spray
# 370        Unbalanced fertilizer use         Use sticky traps and neem oil
# 391               Uncontrolled weeds  Integrated Pest Management practices
# 456                   Delayed sowing          Apply recommended fungicides
# 467  Heavy rainfall and waterlogging    Crop rotation and field sanitation
# 468                    Poor drainage          Apply recommended fungicides
#
#     Control_Type                  Source  Imputed_Flag  \
# 9            IPM     Farmer field report         False
# 56    Biological             PPQS report         False
# 74      Cultural     Farmer field report         False
# 112          IPM               KVK alert         False
# 121          IPM  State Agriculture Dept         False
# 128          IPM               KVK alert         False
# 135     Cultural               KVK alert         False
# 205          IPM     Farmer field report         False
# 209          IPM           ICAR advisory         False
# 215   Biological               KVK alert         False
# 263   Biological           ICAR advisory         False
# 294          IPM             PPQS report         False
# 316     Cultural           ICAR advisory         False
# 356   Biological               KVK alert         False
# 370          IPM               KVK alert         False
# 391          IPM     Farmer field report         False
# 456     Chemical           ICAR advisory         False
# 467     Cultural             PPQS report         False
# 468     Chemical     Farmer field report         False
#
#      Incidence_Percent_Imputed  Year
# 9                         82.9  2025
# 56                        76.1  2025
# 74                        83.5  2025
# 112                       30.0  2025
# 121                       88.6  2025
# 128                       20.8  2025
# 135                       55.7  2025
# 205                       73.7  2025
# 209                       48.3  2025
# 215                       72.8  2025
# 263                       24.4  2025
# 294                       87.5  2025
# 316                       50.3  2025
# 356                       72.7  2025
# 370                       42.3  2025
# 391                       34.1  2025
# 456                       44.9  2025
# 467                       43.3  2025
# 468                       30.9  2025

# %%
# Question 3: Handling missing values in pest incidence data(Bloom's level-4)

# Step 1: Check and print the number of missing values in the 'Incidence_Percent' column
print("No. of empty pest incidence:")
print(df["Incidence_Percent"].isnull().sum())

# Step 2: Fill the missing values in 'Incidence_Percent' with the mean of the column
# This ensures that the column has no empty values for further analysis
df.fillna({"Incidence_Percent": df["Incidence_Percent"].mean()}, inplace=True)

# Step 3: Print the 'Incidence_Percent' column after filling missing values
print("\nIncidence data:\n", df["Incidence_Percent"])

# Step 4: Verify that there are no more missing values in the column
print("\nNo. of empty incidence after imputing:")
print(df["Incidence_Percent"].isnull().sum())
# Out:
# No. of empty pest incidence:
# 25
#
# Incidence data:
#  0      58.2
# 1      59.9
# 2      35.8
# 3      66.8
# 4      14.2
#        ...
# 495    39.6
# 496    34.3
# 497    34.4
# 498    79.6
# 499    48.0
# Name: Incidence_Percent, Length: 500, dtype: float64
#
# No. of empty incidence after imputing:
# 0

# %%
#Question-4 : Group reports by pest type and region (BL-4); Q5: Plot pest incidence trends across years (Blooms level-5)


# This will create groups for each unique combination of pest type and region
grouped_reports = df.groupby(["Pest_Type", "Region"])["Incidence_Percent_Imputed"].mean()

# Calculate the mean of 'Incidence_Percent_Imputed' for each group
# This gives the average pest incidence for each Pest_Type × Region combination

# Print the grouped report

print(grouped_reports)
# Out:
# Pest_Type  Region
# Fungal     Central    54.444444
#            East       50.769231
#            North      48.290566
#            South      55.806557
#            West       42.377419
# Insect     Central    38.223529
#            East       46.472917
#            North      49.137879
#            South      49.953623
#            West       45.297561
# Name: Incidence_Percent_Imputed, dtype: float64
